# %% [markdown]
# ![image.png](attachment:26fcb6e6-2c50-4830-9aea-9771389cc521.png)

# %%
def smart_parking_lot(capacity, vehicle_logs):
    parked = 0
    peak = 0

    for log in vehicle_logs:
        if log == "IN":
            parked += 1
        elif log == "OUT" and parked > 0:
            parked -= 1

        # Track peak usage
        if parked > peak:
            peak = parked

    print("Currently Parked Vehicles:", parked)

    if parked > capacity:
        print("Parking Status: Exceeded Capacity")
    elif parked == capacity:
        print("Parking Status: Full")
    else:
        print("Parking Status: Available")

    print("Peak Usage:", peak)


# Sample Input
smart_parking_lot(50, ["IN", "IN", "IN", "OUT", "IN", "IN", "OUT"])
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available
# Peak Usage: 4

# %% [markdown]
# ![image.png](attachment:4cb8b670-cd50-4b7b-974d-12f18a9e513c.png)

# %%
def estimate_delivery_time(distance, traffic, weather):
    # Base time calculation (5 minutes per km)
    eta = distance * 5

    # Traffic adjustment
    if traffic.lower() == "high":
        eta += 15
    elif traffic.lower() == "medium":
        eta += 8

    # Weather adjustment
    if weather.lower() == "rainy":
        eta += 10
    elif weather.lower() == "storm":
        eta += 20

    print("Estimated Delivery Time:", eta, "minutes")


# Sample Input
estimate_delivery_time(8, "High", "Rainy")
# Out:
# Estimated Delivery Time: 65 minutes

# %% [markdown]
# ![image.png](attachment:19044584-f53d-4fbf-a302-43eac2cea132.png)

# %%
def seat_occupancy(total_seats, booked_seats):
    booked_count = len(booked_seats)
    occupancy = (booked_count / total_seats) * 100

    print("Occupancy:", round(occupancy), "%")

    if occupancy == 100:
        print("Show Status: Housefull")
    elif occupancy >= 75:
        print("Show Status: Almost Full")
        print("Suggestion: Consider Opening Additional Shows")
    else:
        print("Show Status: Available")


# Sample Input
seat_occupancy(200, [1] * 150)
# Out:
# Occupancy: 75 %
# Show Status: Almost Full
# Suggestion: Consider Opening Additional Shows

# %% [markdown]
# ![image.png](attachment:0954eb50-08c1-46f3-ac11-8827925f38a1.png)

# %%
def classify_server_load(cpu_readings):
    total = 0

    for reading in cpu_readings:
        total += reading

    average = total / len(cpu_readings)

    print("Average CPU Load:", round(average), "%")

    if average < 50:
        print("Server Status: Normal")
    elif 50 <= average <= 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")


# Sample Input
classify_server_load([45, 60, 70, 85, 90])
# Out:
# Average CPU Load: 70 %
# Server Status: Warning

# %% [markdown]
# ![image.png](attachment:e263661d-25b3-4d67-8381-c60e5bb6f99b.png)

# %%
def resource_monitor(resource_usage):
    overused = []

    for resource, hours in resource_usage.items():
        if hours > 8:
            overused.append(resource)

    if overused:
        print("Overused Resources:", ", ".join(overused))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")


# Sample Input
resource_monitor({
    "Projector": 6,
    "AC": 9,
    "Lights": 4
})
# Out:
# Overused Resources: AC
# Energy Alert: Yes

# %% [markdown]
# ![image.png](attachment:57881b6d-fac3-4a47-806a-c0aebb86cc06.png)

# %%
def event_registration(capacity, registrations):
    if registrations > capacity:
        confirmed = capacity
        waitlisted = registrations - capacity
        status = "Closed"
    else:
        confirmed = registrations
        waitlisted = 0
        status = "Open"

    print("Confirmed Registrations:", confirmed)
    print("Waitlisted Users:", waitlisted)
    print("Registration Status:", status)


# Sample Input
event_registration(100, 105)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
